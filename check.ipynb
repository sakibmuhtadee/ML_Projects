# %%
import numpy as np
import sys
sys.path.append('/Documents/Machine Learning from Scratch/tools')
from naivebayes import NaiveBayes

from email_preprocess import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4f669861007d> in <module>
#       2 import sys
#       3 sys.path.append('/Documents/Machine Learning from Scratch/tools')
# ----> 4 from naivebayes import NaiveBayes
#       5
#       6 from email_preprocess import *
#
# ModuleNotFoundError: No module named 'naivebayes'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-0aad45671ee9> in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 from naivebayes import NaiveBayes
#       7
#       8
#
# ModuleNotFoundError: No module named 'naivebayes'
